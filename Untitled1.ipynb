# %%
import os

# %%
path = 'runs/exp8/train_batch0.jpg'
isFile = os.path.isfile(path)
print(isFile)
# Out:
# False

# %%
#import matplotlib as plt
# %matplotlib inline
from IPython.display import Image
import glob

# %%
path = 'yolov5/runs/exp8/train_batch0.jpg'
Image(filename=path)
